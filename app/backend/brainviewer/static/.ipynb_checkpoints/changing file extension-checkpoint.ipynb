# %%
# %ls
# Out:
# 'changing file extension.ipynb'   images_data/

# %%
import os

folder = 'images_data/244'

for filename in os.listdir(folder):
    if filename.lower().endswith('.jpg'):
        base = filename.rsplit('.', 1)[0]
        old_path = os.path.join(folder, filename)
        new_path = os.path.join(folder, base + '.png')
        os.rename(old_path, new_path)
        print(f'Renamed: {filename} → {base}.png')
# Out:
# Converted: nissl-2029.jpg → nissl-2029.png
# Converted: bfi-1701.jpg → bfi-1701.png
# Converted: bfi-1369.jpg → bfi-1369.png
# Converted: bfi-2473.jpg → bfi-2473.png
# Converted: bfi-1686.jpg → bfi-1686.png
# Converted: bfi-168.jpg → bfi-168.png
# Converted: nissl-355.jpg → nissl-355.png
# Converted: bfi-2303.jpg → bfi-2303.png
# Converted: bfi-839.jpg → bfi-839.png
# Converted: bfi-875.jpg → bfi-875.png
# Converted: bfi-1402.jpg → bfi-1402.png
# Converted: bfi-1821.jpg → bfi-1821.png
# Converted: bfi-60.jpg → bfi-60.png
# Converted: nissl-1753.jpg → nissl-1753.png
# Converted: bfi-1503.jpg → bfi-1503.png
# Converted: bfi-1771.jpg → bfi-1771.png
# Converted: nissl-1618.jpg → nissl-1618.png
# Converted: nissl-493.jpg → nissl-493.png
# Converted: bfi-1032.jpg → bfi-1032.png
# Converted: nissl-547.jpg → nissl-547.png
# Converted: bfi-2205.jpg → bfi-2205.png
# Converted: bfi-1063.jpg → bfi-1063.png
# Converted: nissl-154.jpg → nissl-154.png
# Converted: bfi-2344.jpg → bfi-2344.png
# Converted: bfi-547.jpg → bfi-547.png
# Converted: bfi-1070.jpg → bfi-1070.png
# Converted: nissl-235.jpg → nissl-235.png
# Converted: bfi-2133.jpg → bfi-2133.png
# Converted: bfi-1393.jpg → bfi-1393.png
# Converted: bfi-1791.jpg → bfi-1791.png
# Converted: bfi-1233.jpg → bfi-1233.png
# Converted: bfi-125.jpg → bfi-125.png
# Converted: bfi-1546.jpg → bfi-1546.png
# Converted: nissl-22.jpg → nissl-22.png
# Converted: bfi-1873.jpg → bfi-1873.png
# Converted: bfi-2262.jpg → bfi-2262.png
# Converted: bfi-1618.jpg → bfi-1618.png
# Converted: nissl-532.jpg → nissl-532.png
# Converted: bfi-2098.jpg → bfi-2098.png
# Converted: bfi-1807.jpg → bfi-1807.png
# Converted: nissl-1330.jpg → nissl-1330.png
# Converted: bfi-40.jpg → bfi-40.png
# Converted: bfi-582.jpg → bfi-582.png
# Converted: nissl-1879.jpg → nissl-1879.png
# Converted: bfi-1849.jpg → bfi-1849.png
# Converted: bfi-1897.jpg → bfi-1897.png
# Converted: bfi-1348.jpg → bfi-1348.png
# Converted: bfi-613.jpg → bfi-613.png
# Converted: bfi-433.jpg → bfi-433.png
# Converted: bfi-1521.jpg → bfi-1521.png
# Converted: nissl-274.jpg → nissl-274.png
# Converted: bfi-2445.jpg → bfi-2445.png
# Converted: bfi-2188.jpg → bfi-2188.png
# Converted: bfi-878.jpg → bfi-878.png
# Converted: bfi-129.jpg → bfi-129.png
# Converted: bfi-57.jpg → bfi-57.png
# Converted: bfi-1525.jpg → bfi-1525.png
# Converted: bfi-1329.jpg → bfi-1329.png
# Converted: bfi-1826.jpg → bfi-1826.png
# Converted: bfi-479.jpg → bfi-479.png
# Converted: bfi-761.jpg → bfi-761.png
# Converted: bfi-1015.jpg → bfi-1015.png
# Converted: bfi-949.jpg → bfi-949.png
# Converted: nissl-367.jpg → nissl-367.png
# Converted: nissl-1690.jpg → nissl-1690.png
# Converted: bfi-102.jpg → bfi-102.png
# Converted: bfi-745.jpg → bfi-745.png
# Converted: bfi-963.jpg → bfi-963.png
# Converted: nissl-175.jpg → nissl-175.png
# Converted: bfi-712.jpg → bfi-712.png
# Converted: nissl-769.jpg → nissl-769.png
# Converted: nissl-286.jpg → nissl-286.png
# Converted: bfi-717.jpg → bfi-717.png
# Converted: bfi-577.jpg → bfi-577.png
# Converted: nissl-1987.jpg → nissl-1987.png
# Converted: bfi-505.jpg → bfi-505.png
# Converted: bfi-786.jpg → bfi-786.png
# Converted: bfi-2169.jpg → bfi-2169.png
# Converted: bfi-865.jpg → bfi-865.png
# Converted: bfi-1236.jpg → bfi-1236.png
# Converted: bfi-1051.jpg → bfi-1051.png
# Converted: bfi-111.jpg → bfi-111.png
# Converted: nissl-739.jpg → nissl-739.png
# Converted: nissl-1984.jpg → nissl-1984.png
# Converted: bfi-2046.jpg → bfi-2046.png
# Converted: nissl-2062.jpg → nissl-2062.png
# Converted: bfi-415.jpg → bfi-415.png
# Converted: bfi-2005.jpg → bfi-2005.png
# Converted: nissl-1876.jpg → nissl-1876.png
# Converted: bfi-2332.jpg → bfi-2332.png
# Converted: bfi-234.jpg → bfi-234.png
# Converted: bfi-1619.jpg → bfi-1619.png
# Converted: bfi-1507.jpg → bfi-1507.png
# Converted: bfi-134.jpg → bfi-134.png
# Converted: bfi-650.jpg → bfi-650.png
# Converted: bfi-777.jpg → bfi-777.png
# Converted: bfi-2249.jpg → bfi-2249.png
# Converted: nissl-1219.jpg → nissl-1219.png
# Converted: bfi-1064.jpg → bfi-1064.png
# Converted: nissl-1429.jpg → nissl-1429.png
# Converted: bfi-985.jpg → bfi-985.png
# Converted: bfi-200.jpg → bfi-200.png
# Converted: bfi-756.jpg → bfi-756.png
# Converted: bfi-702.jpg → bfi-702.png
# Converted: bfi-1446.jpg → bfi-1446.png
# Converted: bfi-24.jpg → bfi-24.png
# Converted: nissl-853.jpg → nissl-853.png
# Converted: bfi-22.jpg → bfi-22.png
# Converted: bfi-1400.jpg → bfi-1400.png
# Converted: nissl-2077.jpg → nissl-2077.png
# Converted: bfi-2252.jpg → bfi-2252.png
# Converted: bfi-411.jpg → bfi-411.png
# Converted: bfi-1381.jpg → bfi-1381.png
# Converted: bfi-2301.jpg → bfi-2301.png
# Converted: bfi-233.jpg → bfi-233.png
# Converted: bfi-2070.jpg → bfi-2070.png
# Converted: bfi-929.jpg → bfi-929.png
# Converted: bfi-2069.jpg → bfi-2069.png
# Converted: bfi-1290.jpg → bfi-1290.png
# Converted: bfi-1385.jpg → bfi-1385.png
# Converted: bfi-9.jpg → bfi-9.png
# Converted: bfi-490.jpg → bfi-490.png
# Converted: bfi-1838.jpg → bfi-1838.png
# Converted: nissl-2218.jpg → nissl-2218.png
# Converted: bfi-797.jpg → bfi-797.png
# Converted: bfi-1001.jpg → bfi-1001.png
# Converted: bfi-1605.jpg → bfi-1605.png
# Converted: bfi-2421.jpg → bfi-2421.png
# Converted: nissl-388.jpg → nissl-388.png
# Converted: bfi-720.jpg → bfi-720.png
# Converted: bfi-1671.jpg → bfi-1671.png
# Converted: bfi-877.jpg → bfi-877.png
# Converted: bfi-173.jpg → bfi-173.png
# Converted: bfi-1371.jpg → bfi-1371.png
# Converted: bfi-1257.jpg → bfi-1257.png
# Converted: nissl-481.jpg → nissl-481.png
# Converted: nissl-448.jpg → nissl-448.png
# Converted: bfi-29.jpg → bfi-29.png
# Converted: nissl-2599.jpg → nissl-2599.png
# Converted: nissl-358.jpg → nissl-358.png
# Converted: bfi-919.jpg → bfi-919.png
# Converted: nissl-1021.jpg → nissl-1021.png
# Converted: bfi-1749.jpg → bfi-1749.png
# Converted: bfi-517.jpg → bfi-517.png
# Converted: bfi-843.jpg → bfi-843.png
# Converted: bfi-1346.jpg → bfi-1346.png
# Converted: nissl-2083.jpg → nissl-2083.png
# Converted: nissl-400.jpg → nissl-400.png
# Converted: bfi-1368.jpg → bfi-1368.png
# Converted: bfi-564.jpg → bfi-564.png
# Converted: nissl-1963.jpg → nissl-1963.png
# Converted: bfi-297.jpg → bfi-297.png
# Converted: bfi-840.jpg → bfi-840.png
# Converted: bfi-813.jpg → bfi-813.png
# Converted: nissl-2596.jpg → nissl-2596.png
# Converted: bfi-1481.jpg → bfi-1481.png
# Converted: nissl-403.jpg → nissl-403.png
# Converted: bfi-1617.jpg → bfi-1617.png
# Converted: bfi-528.jpg → bfi-528.png
# Converted: bfi-2283.jpg → bfi-2283.png
# Converted: nissl-928.jpg → nissl-928.png
# Converted: bfi-858.jpg → bfi-858.png
# Converted: nissl-1006.jpg → nissl-1006.png
# Converted: bfi-1427.jpg → bfi-1427.png
# Converted: bfi-468.jpg → bfi-468.png
# Converted: nissl-661.jpg → nissl-661.png
# Converted: bfi-2426.jpg → bfi-2426.png
# Converted: bfi-1941.jpg → bfi-1941.png
# Converted: bfi-140.jpg → bfi-140.png
# Converted: nissl-253.jpg → nissl-253.png
# Converted: bfi-254.jpg → bfi-254.png
# Converted: nissl-1237.jpg → nissl-1237.png
# Converted: bfi-1841.jpg → bfi-1841.png
# Converted: nissl-127.jpg → nissl-127.png
# Converted: bfi-484.jpg → bfi-484.png
# Converted: bfi-1635.jpg → bfi-1635.png
# Converted: bfi-2304.jpg → bfi-2304.png
# Converted: nissl-169.jpg → nissl-169.png
# Converted: bfi-1137.jpg → bfi-1137.png
# Converted: bfi-532.jpg → bfi-532.png
# Converted: bfi-80.jpg → bfi-80.png
# Converted: nissl-745.jpg → nissl-745.png
# Converted: bfi-1843.jpg → bfi-1843.png
# Converted: bfi-385.jpg → bfi-385.png
# Converted: bfi-2443.jpg → bfi-2443.png
# Converted: nissl-1615.jpg → nissl-1615.png
# Converted: bfi-1860.jpg → bfi-1860.png
# Converted: nissl-730.jpg → nissl-730.png
# Converted: bfi-1419.jpg → bfi-1419.png
# Converted: nissl-706.jpg → nissl-706.png
# Converted: bfi-619.jpg → bfi-619.png
# Converted: nissl-2590.jpg → nissl-2590.png
# Converted: bfi-2087.jpg → bfi-2087.png
# Converted: nissl-1687.jpg → nissl-1687.png
# Converted: bfi-1491.jpg → bfi-1491.png
# Converted: bfi-1222.jpg → bfi-1222.png
# Converted: bfi-1423.jpg → bfi-1423.png
# Converted: bfi-524.jpg → bfi-524.png
# Converted: bfi-1312.jpg → bfi-1312.png
# Converted: nissl-1969.jpg → nissl-1969.png
# Converted: bfi-305.jpg → bfi-305.png
# Converted: bfi-1009.jpg → bfi-1009.png
# Converted: nissl-616.jpg → nissl-616.png
# Converted: bfi-28.jpg → bfi-28.png
# Converted: nissl-1279.jpg → nissl-1279.png
# Converted: bfi-1629.jpg → bfi-1629.png
# Converted: bfi-1512.jpg → bfi-1512.png
# Converted: bfi-1548.jpg → bfi-1548.png
# Converted: bfi-2236.jpg → bfi-2236.png
# Converted: nissl-1438.jpg → nissl-1438.png
# Converted: bfi-2327.jpg → bfi-2327.png
# Converted: bfi-1604.jpg → bfi-1604.png
# Converted: bfi-1931.jpg → bfi-1931.png
# Converted: bfi-1888.jpg → bfi-1888.png
# Converted: bfi-703.jpg → bfi-703.png
# Converted: nissl-1804.jpg → nissl-1804.png
# Converted: bfi-2082.jpg → bfi-2082.png
# Converted: nissl-631.jpg → nissl-631.png
# Converted: bfi-1519.jpg → bfi-1519.png
# Converted: bfi-1213.jpg → bfi-1213.png
# Converted: bfi-204.jpg → bfi-204.png
# Converted: bfi-65.jpg → bfi-65.png
# Converted: bfi-1723.jpg → bfi-1723.png
# Converted: bfi-1211.jpg → bfi-1211.png
# Converted: nissl-1024.jpg → nissl-1024.png
# Converted: bfi-2346.jpg → bfi-2346.png
# Converted: bfi-2002.jpg → bfi-2002.png
# Converted: bfi-299.jpg → bfi-299.png
# Converted: bfi-2240.jpg → bfi-2240.png
# Converted: bfi-294.jpg → bfi-294.png
# Converted: bfi-1037.jpg → bfi-1037.png
# Converted: bfi-84.jpg → bfi-84.png
# Converted: bfi-2491.jpg → bfi-2491.png
# Converted: bfi-552.jpg → bfi-552.png
# Converted: bfi-2255.jpg → bfi-2255.png
# Converted: bfi-2083.jpg → bfi-2083.png
# Converted: bfi-1929.jpg → bfi-1929.png
# Converted: bfi-854.jpg → bfi-854.png
# Converted: nissl-289.jpg → nissl-289.png
# Converted: nissl-892.jpg → nissl-892.png
# Converted: bfi-1883.jpg → bfi-1883.png
# Converted: bfi-1440.jpg → bfi-1440.png
# Converted: bfi-2467.jpg → bfi-2467.png
# Converted: bfi-116.jpg → bfi-116.png
# Converted: nissl-1051.jpg → nissl-1051.png
# Converted: nissl-268.jpg → nissl-268.png
# Converted: bfi-1179.jpg → bfi-1179.png
# Converted: bfi-2167.jpg → bfi-2167.png
# Converted: bfi-1479.jpg → bfi-1479.png
# Converted: bfi-406.jpg → bfi-406.png
# Converted: bfi-1842.jpg → bfi-1842.png
# Converted: bfi-152.jpg → bfi-152.png
# Converted: bfi-172.jpg → bfi-172.png
# Converted: bfi-73.jpg → bfi-73.png
# Converted: bfi-705.jpg → bfi-705.png
# Converted: bfi-1992.jpg → bfi-1992.png
# Converted: bfi-870.jpg → bfi-870.png
# Converted: bfi-1858.jpg → bfi-1858.png
# Converted: bfi-46.jpg → bfi-46.png
# Converted: bfi-974.jpg → bfi-974.png
# Converted: bfi-947.jpg → bfi-947.png
# Converted: bfi-788.jpg → bfi-788.png
# Converted: bfi-530.jpg → bfi-530.png
# Converted: bfi-390.jpg → bfi-390.png
# Converted: bfi-1763.jpg → bfi-1763.png
# Converted: bfi-1146.jpg → bfi-1146.png
# Converted: bfi-85.jpg → bfi-85.png
# Converted: bfi-50.jpg → bfi-50.png
# Converted: bfi-2003.jpg → bfi-2003.png
# Converted: nissl-2629.jpg → nissl-2629.png
# Converted: nissl-1720.jpg → nissl-1720.png
# Converted: bfi-1909.jpg → bfi-1909.png
# Converted: bfi-2384.jpg → bfi-2384.png
# Converted: bfi-2111.jpg → bfi-2111.png
# Converted: nissl-709.jpg → nissl-709.png
# Converted: bfi-2379.jpg → bfi-2379.png
# Converted: bfi-576.jpg → bfi-576.png
# Converted: bfi-2399.jpg → bfi-2399.png
# Converted: bfi-891.jpg → bfi-891.png
# Converted: bfi-97.jpg → bfi-97.png
# Converted: bfi-2435.jpg → bfi-2435.png
# Converted: nissl-313.jpg → nissl-313.png
# Converted: nissl-208.jpg → nissl-208.png
# Converted: bfi-1603.jpg → bfi-1603.png
# Converted: bfi-1011.jpg → bfi-1011.png
# Converted: nissl-691.jpg → nissl-691.png
# Converted: nissl-1300.jpg → nissl-1300.png
# Converted: bfi-1451.jpg → bfi-1451.png
# Converted: nissl-1663.jpg → nissl-1663.png
# Converted: nissl-2350.jpg → nissl-2350.png
# Converted: bfi-707.jpg → bfi-707.png
# Converted: bfi-126.jpg → bfi-126.png
# Converted: bfi-474.jpg → bfi-474.png
# Converted: nissl-2020.jpg → nissl-2020.png
# Converted: nissl-2305.jpg → nissl-2305.png
# Converted: bfi-886.jpg → bfi-886.png
# Converted: bfi-894.jpg → bfi-894.png
# Converted: bfi-1752.jpg → bfi-1752.png
# Converted: nissl-1585.jpg → nissl-1585.png
# Converted: bfi-1299.jpg → bfi-1299.png
# Converted: bfi-1719.jpg → bfi-1719.png
# Converted: bfi-1433.jpg → bfi-1433.png
# Converted: bfi-1689.jpg → bfi-1689.png
# Converted: bfi-1993.jpg → bfi-1993.png
# Converted: bfi-959.jpg → bfi-959.png
# Converted: bfi-1135.jpg → bfi-1135.png
# Converted: nissl-2386.jpg → nissl-2386.png
# Converted: nissl-862.jpg → nissl-862.png
# Converted: bfi-2471.jpg → bfi-2471.png
# Converted: nissl-1510.jpg → nissl-1510.png
# Converted: bfi-768.jpg → bfi-768.png
# Converted: nissl-1381.jpg → nissl-1381.png
# Converted: bfi-2320.jpg → bfi-2320.png
# Converted: nissl-382.jpg → nissl-382.png
# Converted: bfi-771.jpg → bfi-771.png
# Converted: bfi-456.jpg → bfi-456.png
# Converted: bfi-1878.jpg → bfi-1878.png
# Converted: bfi-2040.jpg → bfi-2040.png
# Converted: bfi-1652.jpg → bfi-1652.png
# Converted: bfi-1364.jpg → bfi-1364.png
# Converted: bfi-1706.jpg → bfi-1706.png
# Converted: bfi-2037.jpg → bfi-2037.png
# Converted: bfi-2114.jpg → bfi-2114.png
# Converted: bfi-2118.jpg → bfi-2118.png
# Converted: bfi-955.jpg → bfi-955.png
# Converted: nissl-775.jpg → nissl-775.png
# Converted: bfi-226.jpg → bfi-226.png
# Converted: nissl-670.jpg → nissl-670.png
# Converted: bfi-117.jpg → bfi-117.png
# Converted: bfi-403.jpg → bfi-403.png
# Converted: bfi-578.jpg → bfi-578.png
# Converted: bfi-243.jpg → bfi-243.png
# Converted: bfi-1705.jpg → bfi-1705.png
# Converted: bfi-2065.jpg → bfi-2065.png
# Converted: bfi-939.jpg → bfi-939.png
# Converted: bfi-1799.jpg → bfi-1799.png
# Converted: bfi-1970.jpg → bfi-1970.png
# Converted: bfi-1740.jpg → bfi-1740.png
# Converted: bfi-639.jpg → bfi-639.png
# Converted: nissl-2422.jpg → nissl-2422.png
# Converted: bfi-914.jpg → bfi-914.png
# Converted: bfi-2490.jpg → bfi-2490.png
# Converted: bfi-2277.jpg → bfi-2277.png
# Converted: bfi-174.jpg → bfi-174.png
# Converted: bfi-1988.jpg → bfi-1988.png
# Converted: bfi-1309.jpg → bfi-1309.png
# Converted: bfi-1721.jpg → bfi-1721.png
# Converted: bfi-286.jpg → bfi-286.png
# Converted: bfi-1408.jpg → bfi-1408.png
# Converted: nissl-1435.jpg → nissl-1435.png
# Converted: bfi-1538.jpg → bfi-1538.png
# Converted: bfi-1700.jpg → bfi-1700.png
# Converted: nissl-184.jpg → nissl-184.png
# Converted: bfi-1156.jpg → bfi-1156.png
# Converted: bfi-1344.jpg → bfi-1344.png
# Converted: bfi-1155.jpg → bfi-1155.png
# Converted: bfi-2387.jpg → bfi-2387.png
# Converted: nissl-1285.jpg → nissl-1285.png
# Converted: nissl-1.jpg → nissl-1.png
# Converted: bfi-1779.jpg → bfi-1779.png
# Converted: bfi-2078.jpg → bfi-2078.png
# Converted: nissl-1411.jpg → nissl-1411.png
# Converted: bfi-976.jpg → bfi-976.png
# Converted: nissl-226.jpg → nissl-226.png
# Converted: bfi-2460.jpg → bfi-2460.png
# Converted: bfi-2080.jpg → bfi-2080.png
# Converted: nissl-283.jpg → nissl-283.png
# Converted: bfi-1952.jpg → bfi-1952.png
# Converted: bfi-1361.jpg → bfi-1361.png
# Converted: bfi-2296.jpg → bfi-2296.png
# Converted: bfi-2391.jpg → bfi-2391.png
# Converted: nissl-2293.jpg → nissl-2293.png
# Converted: bfi-2045.jpg → bfi-2045.png
# Converted: bfi-637.jpg → bfi-637.png
# Converted: bfi-1501.jpg → bfi-1501.png
# Converted: bfi-1827.jpg → bfi-1827.png
# Converted: bfi-1661.jpg → bfi-1661.png
# Converted: bfi-1294.jpg → bfi-1294.png
# Converted: bfi-1643.jpg → bfi-1643.png
# Converted: nissl-1465.jpg → nissl-1465.png
# Converted: bfi-1399.jpg → bfi-1399.png
# Converted: nissl-1702.jpg → nissl-1702.png
# Converted: bfi-1903.jpg → bfi-1903.png
# Converted: bfi-496.jpg → bfi-496.png
# Converted: bfi-622.jpg → bfi-622.png
# Converted: bfi-2219.jpg → bfi-2219.png
# Converted: bfi-750.jpg → bfi-750.png
# Converted: bfi-485.jpg → bfi-485.png
# Converted: bfi-2232.jpg → bfi-2232.png
# Converted: nissl-2110.jpg → nissl-2110.png
# Converted: nissl-199.jpg → nissl-199.png
# Converted: bfi-238.jpg → bfi-238.png
# Converted: nissl-1546.jpg → nissl-1546.png
# Converted: bfi-1914.jpg → bfi-1914.png
# Converted: nissl-1612.jpg → nissl-1612.png
# Converted: bfi-1202.jpg → bfi-1202.png
# Converted: bfi-772.jpg → bfi-772.png
# Converted: nissl-2542.jpg → nissl-2542.png
# Converted: bfi-1020.jpg → bfi-1020.png
# Converted: bfi-817.jpg → bfi-817.png
# Converted: bfi-1716.jpg → bfi-1716.png
# Converted: nissl-466.jpg → nissl-466.png
# Converted: bfi-1999.jpg → bfi-1999.png
# Converted: bfi-1886.jpg → bfi-1886.png
# Converted: nissl-1201.jpg → nissl-1201.png
# Converted: bfi-128.jpg → bfi-128.png
# Converted: bfi-2459.jpg → bfi-2459.png
# Converted: bfi-109.jpg → bfi-109.png
# Converted: bfi-1725.jpg → bfi-1725.png
# Converted: bfi-209.jpg → bfi-209.png
# Converted: bfi-1832.jpg → bfi-1832.png
# Converted: bfi-2353.jpg → bfi-2353.png
# Converted: nissl-1885.jpg → nissl-1885.png
# Converted: bfi-1220.jpg → bfi-1220.png
# Converted: bfi-1122.jpg → bfi-1122.png
# Converted: nissl-2632.jpg → nissl-2632.png
# Converted: bfi-709.jpg → bfi-709.png
# Converted: bfi-1004.jpg → bfi-1004.png
# Converted: nissl-907.jpg → nissl-907.png
# Converted: nissl-1183.jpg → nissl-1183.png
# Converted: nissl-1069.jpg → nissl-1069.png
# Converted: nissl-1735.jpg → nissl-1735.png
# Converted: nissl-1789.jpg → nissl-1789.png
# Converted: bfi-1739.jpg → bfi-1739.png
# Converted: bfi-1533.jpg → bfi-1533.png
# Converted: bfi-171.jpg → bfi-171.png
# Converted: nissl-487.jpg → nissl-487.png
# Converted: bfi-501.jpg → bfi-501.png
# Converted: bfi-378.jpg → bfi-378.png
# Converted: bfi-2333.jpg → bfi-2333.png
# Converted: bfi-1499.jpg → bfi-1499.png
# Converted: nissl-2152.jpg → nissl-2152.png
# Converted: bfi-1126.jpg → bfi-1126.png
# Converted: bfi-2396.jpg → bfi-2396.png
# Converted: bfi-690.jpg → bfi-690.png
# Converted: bfi-1687.jpg → bfi-1687.png
# Converted: bfi-2339.jpg → bfi-2339.png
# Converted: bfi-553.jpg → bfi-553.png
# Converted: bfi-79.jpg → bfi-79.png
# Converted: bfi-424.jpg → bfi-424.png
# Converted: bfi-566.jpg → bfi-566.png
# Converted: bfi-136.jpg → bfi-136.png
# Converted: bfi-1033.jpg → bfi-1033.png
# Converted: nissl-994.jpg → nissl-994.png
# Converted: nissl-2248.jpg → nissl-2248.png
# Converted: bfi-2074.jpg → bfi-2074.png
# Converted: nissl-2188.jpg → nissl-2188.png
# Converted: bfi-2145.jpg → bfi-2145.png
# Converted: bfi-938.jpg → bfi-938.png
# Converted: bfi-1215.jpg → bfi-1215.png
# Converted: bfi-614.jpg → bfi-614.png
# Converted: bfi-826.jpg → bfi-826.png
# Converted: bfi-2370.jpg → bfi-2370.png
# Converted: bfi-2238.jpg → bfi-2238.png
# Converted: bfi-1576.jpg → bfi-1576.png
# Converted: bfi-1356.jpg → bfi-1356.png
# Converted: bfi-1199.jpg → bfi-1199.png
# Converted: nissl-949.jpg → nissl-949.png
# Converted: nissl-1954.jpg → nissl-1954.png
# Converted: bfi-1630.jpg → bfi-1630.png
# Converted: bfi-1727.jpg → bfi-1727.png
# Converted: bfi-231.jpg → bfi-231.png
# Converted: bfi-2200.jpg → bfi-2200.png
# Converted: bfi-2287.jpg → bfi-2287.png
# Converted: nissl-250.jpg → nissl-250.png
# Converted: bfi-1218.jpg → bfi-1218.png
# Converted: bfi-26.jpg → bfi-26.png
# Converted: bfi-2276.jpg → bfi-2276.png
# Converted: bfi-423.jpg → bfi-423.png
# Converted: bfi-1877.jpg → bfi-1877.png
# Converted: bfi-2480.jpg → bfi-2480.png
# Converted: bfi-182.jpg → bfi-182.png
# Converted: nissl-2002.jpg → nissl-2002.png
# Converted: bfi-946.jpg → bfi-946.png
# Converted: nissl-1270.jpg → nissl-1270.png
# Converted: bfi-88.jpg → bfi-88.png
# Converted: bfi-1795.jpg → bfi-1795.png
# Converted: bfi-766.jpg → bfi-766.png
# Converted: bfi-453.jpg → bfi-453.png
# Converted: bfi-2359.jpg → bfi-2359.png
# Converted: bfi-893.jpg → bfi-893.png
# Converted: bfi-279.jpg → bfi-279.png
# Converted: bfi-621.jpg → bfi-621.png
# Converted: nissl-2560.jpg → nissl-2560.png
# Converted: bfi-96.jpg → bfi-96.png
# Converted: bfi-2401.jpg → bfi-2401.png
# Converted: nissl-646.jpg → nissl-646.png
# Converted: bfi-2388.jpg → bfi-2388.png
# Converted: bfi-2278.jpg → bfi-2278.png
# Converted: bfi-2081.jpg → bfi-2081.png
# Converted: nissl-223.jpg → nissl-223.png
# Converted: bfi-1354.jpg → bfi-1354.png
# Converted: bfi-1263.jpg → bfi-1263.png
# Converted: bfi-442.jpg → bfi-442.png
# Converted: bfi-2349.jpg → bfi-2349.png
# Converted: bfi-2050.jpg → bfi-2050.png
# Converted: bfi-1334.jpg → bfi-1334.png
# Converted: bfi-1452.jpg → bfi-1452.png
# Converted: bfi-1726.jpg → bfi-1726.png
# Converted: bfi-2298.jpg → bfi-2298.png
# Converted: nissl-1549.jpg → nissl-1549.png
# Converted: bfi-87.jpg → bfi-87.png
# Converted: bfi-159.jpg → bfi-159.png
# Converted: nissl-1243.jpg → nissl-1243.png
# Converted: bfi-2192.jpg → bfi-2192.png
# Converted: bfi-2450.jpg → bfi-2450.png
# Converted: bfi-1685.jpg → bfi-1685.png
# Converted: bfi-1083.jpg → bfi-1083.png
# Converted: nissl-1888.jpg → nissl-1888.png
# Converted: bfi-1463.jpg → bfi-1463.png
# Converted: bfi-44.jpg → bfi-44.png
# Converted: bfi-807.jpg → bfi-807.png
# Converted: bfi-2390.jpg → bfi-2390.png
# Converted: bfi-1203.jpg → bfi-1203.png
# Converted: bfi-1389.jpg → bfi-1389.png
# Converted: bfi-836.jpg → bfi-836.png
# Converted: bfi-380.jpg → bfi-380.png
# Converted: nissl-826.jpg → nissl-826.png
# Converted: bfi-1104.jpg → bfi-1104.png
# Converted: bfi-1195.jpg → bfi-1195.png
# Converted: bfi-1747.jpg → bfi-1747.png
# Converted: bfi-1468.jpg → bfi-1468.png
# Converted: nissl-571.jpg → nissl-571.png
# Converted: bfi-1939.jpg → bfi-1939.png
# Converted: bfi-1310.jpg → bfi-1310.png
# Converted: bfi-1969.jpg → bfi-1969.png
# Converted: nissl-1177.jpg → nissl-1177.png
# Converted: bfi-1848.jpg → bfi-1848.png
# Converted: bfi-977.jpg → bfi-977.png
# Converted: nissl-2167.jpg → nissl-2167.png
# Converted: bfi-1148.jpg → bfi-1148.png
# Converted: bfi-1302.jpg → bfi-1302.png
# Converted: bfi-734.jpg → bfi-734.png
# Converted: bfi-887.jpg → bfi-887.png
# Converted: bfi-130.jpg → bfi-130.png
# Converted: bfi-431.jpg → bfi-431.png
# Converted: bfi-697.jpg → bfi-697.png
# Converted: bfi-987.jpg → bfi-987.png
# Converted: nissl-1114.jpg → nissl-1114.png
# Converted: bfi-1029.jpg → bfi-1029.png
# Converted: bfi-1065.jpg → bfi-1065.png
# Converted: bfi-162.jpg → bfi-162.png
# Converted: bfi-1085.jpg → bfi-1085.png
# Converted: bfi-137.jpg → bfi-137.png
# Converted: bfi-2420.jpg → bfi-2420.png
# Converted: bfi-2198.jpg → bfi-2198.png
# Converted: nissl-2536.jpg → nissl-2536.png
# Converted: nissl-718.jpg → nissl-718.png
# Converted: bfi-1144.jpg → bfi-1144.png
# Converted: nissl-2410.jpg → nissl-2410.png
# Converted: bfi-860.jpg → bfi-860.png
# Converted: bfi-502.jpg → bfi-502.png
# Converted: bfi-481.jpg → bfi-481.png
# Converted: bfi-1250.jpg → bfi-1250.png
# Converted: bfi-2027.jpg → bfi-2027.png
# Converted: bfi-1342.jpg → bfi-1342.png
# Converted: bfi-672.jpg → bfi-672.png
# Converted: nissl-2173.jpg → nissl-2173.png
# Converted: bfi-1212.jpg → bfi-1212.png
# Converted: bfi-475.jpg → bfi-475.png
# Converted: bfi-954.jpg → bfi-954.png
# Converted: bfi-1267.jpg → bfi-1267.png
# Converted: bfi-1486.jpg → bfi-1486.png
# Converted: bfi-1968.jpg → bfi-1968.png
# Converted: bfi-2347.jpg → bfi-2347.png
# Converted: bfi-1835.jpg → bfi-1835.png
# Converted: bfi-1221.jpg → bfi-1221.png
# Converted: bfi-1717.jpg → bfi-1717.png
# Converted: nissl-526.jpg → nissl-526.png
# Converted: bfi-662.jpg → bfi-662.png
# Converted: bfi-2166.jpg → bfi-2166.png
# Converted: nissl-2356.jpg → nissl-2356.png
# Converted: bfi-773.jpg → bfi-773.png
# Converted: bfi-584.jpg → bfi-584.png
# Converted: bfi-2229.jpg → bfi-2229.png
# Converted: nissl-2650.jpg → nissl-2650.png
# Converted: bfi-1824.jpg → bfi-1824.png
# Converted: nissl-1843.jpg → nissl-1843.png
# Converted: bfi-77.jpg → bfi-77.png
# Converted: bfi-1383.jpg → bfi-1383.png
# Converted: bfi-1896.jpg → bfi-1896.png
# Converted: bfi-1323.jpg → bfi-1323.png
# Converted: bfi-1365.jpg → bfi-1365.png
# Converted: bfi-570.jpg → bfi-570.png
# Converted: bfi-1138.jpg → bfi-1138.png
# Converted: nissl-370.jpg → nissl-370.png
# Converted: nissl-1981.jpg → nissl-1981.png
# Converted: bfi-2121.jpg → bfi-2121.png
# Converted: nissl-2158.jpg → nissl-2158.png
# Converted: bfi-2071.jpg → bfi-2071.png
# Converted: bfi-1578.jpg → bfi-1578.png
# Converted: bfi-206.jpg → bfi-206.png
# Converted: bfi-2400.jpg → bfi-2400.png
# Converted: nissl-2320.jpg → nissl-2320.png
# Converted: bfi-1304.jpg → bfi-1304.png
# Converted: bfi-2209.jpg → bfi-2209.png
# Converted: bfi-12.jpg → bfi-12.png
# Converted: bfi-800.jpg → bfi-800.png
# Converted: bfi-1154.jpg → bfi-1154.png
# Converted: bfi-1812.jpg → bfi-1812.png
# Converted: nissl-1294.jpg → nissl-1294.png
# Converted: bfi-325.jpg → bfi-325.png
# Converted: bfi-1335.jpg → bfi-1335.png
# Converted: bfi-652.jpg → bfi-652.png
# Converted: nissl-1366.jpg → nissl-1366.png
# Converted: bfi-1142.jpg → bfi-1142.png
# Converted: nissl-982.jpg → nissl-982.png
# Converted: bfi-319.jpg → bfi-319.png
# Converted: bfi-1160.jpg → bfi-1160.png
# Converted: bfi-749.jpg → bfi-749.png
# Converted: bfi-2149.jpg → bfi-2149.png
# Converted: bfi-1038.jpg → bfi-1038.png
# Converted: bfi-1974.jpg → bfi-1974.png
# Converted: nissl-79.jpg → nissl-79.png
# Converted: nissl-850.jpg → nissl-850.png
# Converted: bfi-434.jpg → bfi-434.png
# Converted: nissl-1645.jpg → nissl-1645.png
# Converted: bfi-147.jpg → bfi-147.png
# Converted: nissl-2233.jpg → nissl-2233.png
# Converted: bfi-1467.jpg → bfi-1467.png
# Converted: bfi-119.jpg → bfi-119.png
# Converted: bfi-1249.jpg → bfi-1249.png
# Converted: bfi-284.jpg → bfi-284.png
# Converted: bfi-1407.jpg → bfi-1407.png
# Converted: bfi-558.jpg → bfi-558.png
# Converted: bfi-971.jpg → bfi-971.png
# Converted: bfi-1660.jpg → bfi-1660.png
# Converted: nissl-352.jpg → nissl-352.png
# Converted: bfi-1946.jpg → bfi-1946.png
# Converted: bfi-2441.jpg → bfi-2441.png
# Converted: nissl-1162.jpg → nissl-1162.png
# Converted: bfi-1942.jpg → bfi-1942.png
# Converted: bfi-1396.jpg → bfi-1396.png
# Converted: bfi-2057.jpg → bfi-2057.png
# Converted: bfi-1582.jpg → bfi-1582.png
# Converted: bfi-1708.jpg → bfi-1708.png
# Converted: bfi-2210.jpg → bfi-2210.png
# Converted: nissl-2647.jpg → nissl-2647.png
# Converted: bfi-1745.jpg → bfi-1745.png
# Converted: nissl-322.jpg → nissl-322.png
# Converted: bfi-1829.jpg → bfi-1829.png
# Converted: bfi-1353.jpg → bfi-1353.png
# Converted: bfi-727.jpg → bfi-727.png
# Converted: bfi-716.jpg → bfi-716.png
# Converted: nissl-160.jpg → nissl-160.png
# Converted: nissl-1090.jpg → nissl-1090.png
# Converted: bfi-1488.jpg → bfi-1488.png
# Converted: bfi-1357.jpg → bfi-1357.png
# Converted: nissl-2533.jpg → nissl-2533.png
# Converted: bfi-1983.jpg → bfi-1983.png
# Converted: bfi-2095.jpg → bfi-2095.png
# Converted: nissl-1957.jpg → nissl-1957.png
# Converted: bfi-2330.jpg → bfi-2330.png
# Converted: bfi-537.jpg → bfi-537.png
# Converted: nissl-835.jpg → nissl-835.png
# Converted: bfi-1891.jpg → bfi-1891.png
# Converted: bfi-1112.jpg → bfi-1112.png
# Converted: nissl-1972.jpg → nissl-1972.png
# Converted: nissl-379.jpg → nissl-379.png
# Converted: nissl-2089.jpg → nissl-2089.png
# Converted: bfi-1133.jpg → bfi-1133.png
# Converted: nissl-805.jpg → nissl-805.png
# Converted: bfi-1918.jpg → bfi-1918.png
# Converted: bfi-311.jpg → bfi-311.png
# Converted: bfi-2220.jpg → bfi-2220.png
# Converted: bfi-661.jpg → bfi-661.png
# Converted: bfi-656.jpg → bfi-656.png
# Converted: bfi-1816.jpg → bfi-1816.png
# Converted: bfi-2486.jpg → bfi-2486.png
# Converted: bfi-876.jpg → bfi-876.png
# Converted: bfi-103.jpg → bfi-103.png
# Converted: bfi-2115.jpg → bfi-2115.png
# Converted: bfi-237.jpg → bfi-237.png
# Converted: bfi-309.jpg → bfi-309.png
# Converted: bfi-1100.jpg → bfi-1100.png
# Converted: nissl-823.jpg → nissl-823.png
# Converted: bfi-464.jpg → bfi-464.png
# Converted: bfi-1967.jpg → bfi-1967.png
# Converted: bfi-1247.jpg → bfi-1247.png
# Converted: bfi-625.jpg → bfi-625.png
# Converted: nissl-508.jpg → nissl-508.png
# Converted: bfi-336.jpg → bfi-336.png
# Converted: bfi-2109.jpg → bfi-2109.png
# Converted: bfi-216.jpg → bfi-216.png
# Converted: nissl-421.jpg → nissl-421.png
# Converted: bfi-2021.jpg → bfi-2021.png
# Converted: nissl-2611.jpg → nissl-2611.png
# Converted: bfi-324.jpg → bfi-324.png
# Converted: bfi-61.jpg → bfi-61.png
# Converted: bfi-815.jpg → bfi-815.png
# Converted: bfi-2007.jpg → bfi-2007.png
# Converted: bfi-2058.jpg → bfi-2058.png
# Converted: bfi-542.jpg → bfi-542.png
# Converted: bfi-2314.jpg → bfi-2314.png
# Converted: bfi-1350.jpg → bfi-1350.png
# Converted: bfi-2310.jpg → bfi-2310.png
# Converted: nissl-133.jpg → nissl-133.png
# Converted: bfi-413.jpg → bfi-413.png
# Converted: bfi-1124.jpg → bfi-1124.png
# Converted: bfi-1514.jpg → bfi-1514.png
# Converted: nissl-55.jpg → nissl-55.png
# Converted: bfi-169.jpg → bfi-169.png
# Converted: nissl-1552.jpg → nissl-1552.png
# Converted: bfi-196.jpg → bfi-196.png
# Converted: bfi-587.jpg → bfi-587.png
# Converted: bfi-1471.jpg → bfi-1471.png
# Converted: nissl-2473.jpg → nissl-2473.png
# Converted: bfi-1750.jpg → bfi-1750.png
# Converted: bfi-1014.jpg → bfi-1014.png
# Converted: bfi-53.jpg → bfi-53.png
# Converted: bfi-1443.jpg → bfi-1443.png
# Converted: nissl-2620.jpg → nissl-2620.png
# Converted: nissl-736.jpg → nissl-736.png
# Converted: bfi-789.jpg → bfi-789.png
# Converted: nissl-1897.jpg → nissl-1897.png
# Converted: nissl-652.jpg → nissl-652.png
# Converted: nissl-1462.jpg → nissl-1462.png
# Converted: bfi-1628.jpg → bfi-1628.png
# Converted: bfi-2291.jpg → bfi-2291.png
# Converted: bfi-368.jpg → bfi-368.png
# Converted: bfi-1194.jpg → bfi-1194.png
# Converted: bfi-2434.jpg → bfi-2434.png
# Converted: bfi-825.jpg → bfi-825.png
# Converted: bfi-2000.jpg → bfi-2000.png
# Converted: bfi-2455.jpg → bfi-2455.png
# Converted: nissl-232.jpg → nissl-232.png
# Converted: bfi-214.jpg → bfi-214.png
# Converted: nissl-2353.jpg → nissl-2353.png
# Converted: bfi-801.jpg → bfi-801.png
# Converted: nissl-802.jpg → nissl-802.png
# Converted: bfi-1042.jpg → bfi-1042.png
# Converted: bfi-187.jpg → bfi-187.png
# Converted: bfi-752.jpg → bfi-752.png
# Converted: nissl-112.jpg → nissl-112.png
# Converted: nissl-136.jpg → nissl-136.png
# Converted: bfi-0.jpg → bfi-0.png
# Converted: nissl-1609.jpg → nissl-1609.png
# Converted: nissl-1951.jpg → nissl-1951.png
# Converted: bfi-131.jpg → bfi-131.png
# Converted: bfi-882.jpg → bfi-882.png
# Converted: nissl-2125.jpg → nissl-2125.png
# Converted: bfi-1870.jpg → bfi-1870.png
# Converted: bfi-751.jpg → bfi-751.png
# Converted: bfi-1223.jpg → bfi-1223.png
# Converted: nissl-2635.jpg → nissl-2635.png
# Converted: nissl-1321.jpg → nissl-1321.png
# Converted: bfi-1597.jpg → bfi-1597.png
# Converted: bfi-2173.jpg → bfi-2173.png
# Converted: bfi-176.jpg → bfi-176.png
# Converted: bfi-1119.jpg → bfi-1119.png
# Converted: nissl-2389.jpg → nissl-2389.png
# Converted: bfi-2206.jpg → bfi-2206.png
# Converted: bfi-156.jpg → bfi-156.png
# Converted: nissl-1795.jpg → nissl-1795.png
# Converted: bfi-654.jpg → bfi-654.png
# Converted: bfi-42.jpg → bfi-42.png
# Converted: bfi-2223.jpg → bfi-2223.png
# Converted: nissl-2431.jpg → nissl-2431.png
# Converted: bfi-2207.jpg → bfi-2207.png
# Converted: bfi-1679.jpg → bfi-1679.png
# Converted: bfi-857.jpg → bfi-857.png
# Converted: bfi-72.jpg → bfi-72.png
# Converted: bfi-268.jpg → bfi-268.png
# Converted: bfi-2162.jpg → bfi-2162.png
# Converted: bfi-2453.jpg → bfi-2453.png
# Converted: nissl-1261.jpg → nissl-1261.png
# Converted: bfi-334.jpg → bfi-334.png
# Converted: nissl-748.jpg → nissl-748.png
# Converted: bfi-303.jpg → bfi-303.png
# Converted: nissl-2086.jpg → nissl-2086.png
# Converted: bfi-567.jpg → bfi-567.png
# Converted: nissl-538.jpg → nissl-538.png
# Converted: bfi-227.jpg → bfi-227.png
# Converted: nissl-2548.jpg → nissl-2548.png
# Converted: bfi-1114.jpg → bfi-1114.png
# Converted: nissl-361.jpg → nissl-361.png
# Converted: nissl-667.jpg → nissl-667.png
# Converted: bfi-541.jpg → bfi-541.png
# Converted: bfi-1712.jpg → bfi-1712.png
# Converted: nissl-2194.jpg → nissl-2194.png
# Converted: bfi-1770.jpg → bfi-1770.png
# Converted: bfi-1895.jpg → bfi-1895.png
# Converted: nissl-781.jpg → nissl-781.png
# Converted: bfi-1239.jpg → bfi-1239.png
# Converted: bfi-1714.jpg → bfi-1714.png
# Converted: bfi-1190.jpg → bfi-1190.png
# Converted: bfi-1989.jpg → bfi-1989.png
# Converted: bfi-91.jpg → bfi-91.png
# Converted: bfi-1041.jpg → bfi-1041.png
# Converted: bfi-908.jpg → bfi-908.png
# Converted: nissl-7.jpg → nissl-7.png
# Converted: bfi-1470.jpg → bfi-1470.png
# Converted: bfi-549.jpg → bfi-549.png
# Converted: bfi-1555.jpg → bfi-1555.png
# Converted: bfi-644.jpg → bfi-644.png
# Converted: nissl-163.jpg → nissl-163.png
# Converted: nissl-2329.jpg → nissl-2329.png
# Converted: nissl-727.jpg → nissl-727.png
# Converted: bfi-1804.jpg → bfi-1804.png
# Converted: bfi-586.jpg → bfi-586.png
# Converted: bfi-1536.jpg → bfi-1536.png
# Converted: nissl-1942.jpg → nissl-1942.png
# Converted: bfi-1159.jpg → bfi-1159.png
# Converted: bfi-1567.jpg → bfi-1567.png
# Converted: bfi-1000.jpg → bfi-1000.png
# Converted: bfi-1621.jpg → bfi-1621.png
# Converted: bfi-219.jpg → bfi-219.png
# Converted: bfi-419.jpg → bfi-419.png
# Converted: bfi-272.jpg → bfi-272.png
# Converted: bfi-1473.jpg → bfi-1473.png
# Converted: bfi-460.jpg → bfi-460.png
# Converted: nissl-1774.jpg → nissl-1774.png
# Converted: nissl-2041.jpg → nissl-2041.png
# Converted: bfi-1161.jpg → bfi-1161.png
# Converted: bfi-340.jpg → bfi-340.png
# Converted: bfi-979.jpg → bfi-979.png
# Converted: bfi-43.jpg → bfi-43.png
# Converted: bfi-531.jpg → bfi-531.png
# Converted: bfi-748.jpg → bfi-748.png
# Converted: bfi-863.jpg → bfi-863.png
# Converted: nissl-2626.jpg → nissl-2626.png
# Converted: bfi-357.jpg → bfi-357.png
# Converted: bfi-834.jpg → bfi-834.png
# Converted: bfi-2308.jpg → bfi-2308.png
# Converted: nissl-2512.jpg → nissl-2512.png
# Converted: bfi-248.jpg → bfi-248.png
# Converted: bfi-236.jpg → bfi-236.png
# Converted: bfi-1656.jpg → bfi-1656.png
# Converted: nissl-1414.jpg → nissl-1414.png
# Converted: bfi-1796.jpg → bfi-1796.png
# Converted: bfi-54.jpg → bfi-54.png
# Converted: nissl-2641.jpg → nissl-2641.png
# Converted: bfi-721.jpg → bfi-721.png
# Converted: bfi-1291.jpg → bfi-1291.png
# Converted: bfi-2030.jpg → bfi-2030.png
# Converted: bfi-1181.jpg → bfi-1181.png
# Converted: bfi-1454.jpg → bfi-1454.png
# Converted: bfi-2302.jpg → bfi-2302.png
# Converted: bfi-1736.jpg → bfi-1736.png
# Converted: nissl-271.jpg → nissl-271.png
# Converted: bfi-1158.jpg → bfi-1158.png
# Converted: bfi-94.jpg → bfi-94.png
# Converted: bfi-1881.jpg → bfi-1881.png
# Converted: bfi-1182.jpg → bfi-1182.png
# Converted: bfi-2147.jpg → bfi-2147.png
# Converted: bfi-942.jpg → bfi-942.png
# Converted: bfi-1127.jpg → bfi-1127.png
# Converted: nissl-937.jpg → nissl-937.png
# Converted: bfi-230.jpg → bfi-230.png
# Converted: bfi-289.jpg → bfi-289.png
# Converted: nissl-2587.jpg → nissl-2587.png
# Converted: bfi-2433.jpg → bfi-2433.png
# Converted: bfi-816.jpg → bfi-816.png
# Converted: bfi-930.jpg → bfi-930.png
# Converted: bfi-2410.jpg → bfi-2410.png
# Converted: bfi-1691.jpg → bfi-1691.png
# Converted: bfi-1280.jpg → bfi-1280.png
# Converted: bfi-2032.jpg → bfi-2032.png
# Converted: bfi-866.jpg → bfi-866.png
# Converted: nissl-997.jpg → nissl-997.png
# Converted: bfi-301.jpg → bfi-301.png
# Converted: bfi-210.jpg → bfi-210.png
# Converted: bfi-1889.jpg → bfi-1889.png
# Converted: nissl-238.jpg → nissl-238.png
# Converted: bfi-645.jpg → bfi-645.png
# Converted: nissl-1966.jpg → nissl-1966.png
# Converted: bfi-1854.jpg → bfi-1854.png
# Converted: bfi-572.jpg → bfi-572.png
# Converted: bfi-809.jpg → bfi-809.png
# Converted: nissl-1732.jpg → nissl-1732.png
# Converted: nissl-1297.jpg → nissl-1297.png
# Converted: bfi-1806.jpg → bfi-1806.png
# Converted: bfi-459.jpg → bfi-459.png
# Converted: bfi-1240.jpg → bfi-1240.png
# Converted: bfi-2215.jpg → bfi-2215.png
# Converted: bfi-982.jpg → bfi-982.png
# Converted: nissl-13.jpg → nissl-13.png
# Converted: bfi-1898.jpg → bfi-1898.png
# Converted: bfi-1908.jpg → bfi-1908.png
# Converted: bfi-1566.jpg → bfi-1566.png
# Converted: bfi-1678.jpg → bfi-1678.png
# Converted: bfi-1802.jpg → bfi-1802.png
# Converted: bfi-1787.jpg → bfi-1787.png
# Converted: bfi-1715.jpg → bfi-1715.png
# Converted: bfi-1682.jpg → bfi-1682.png
# Converted: bfi-1387.jpg → bfi-1387.png
# Converted: bfi-642.jpg → bfi-642.png
# Converted: bfi-1887.jpg → bfi-1887.png
# Converted: bfi-550.jpg → bfi-550.png
# Converted: bfi-1704.jpg → bfi-1704.png
# Converted: bfi-143.jpg → bfi-143.png
# Converted: nissl-778.jpg → nissl-778.png
# Converted: bfi-2064.jpg → bfi-2064.png
# Converted: bfi-725.jpg → bfi-725.png
# Converted: bfi-1990.jpg → bfi-1990.png
# Converted: bfi-1650.jpg → bfi-1650.png
# Converted: bfi-290.jpg → bfi-290.png
# Converted: nissl-46.jpg → nissl-46.png
# Converted: nissl-2488.jpg → nissl-2488.png
# Converted: bfi-2100.jpg → bfi-2100.png
# Converted: bfi-198.jpg → bfi-198.png
# Converted: bfi-1535.jpg → bfi-1535.png
# Converted: bfi-972.jpg → bfi-972.png
# Converted: bfi-859.jpg → bfi-859.png
# Converted: bfi-1485.jpg → bfi-1485.png
# Converted: nissl-190.jpg → nissl-190.png
# Converted: bfi-616.jpg → bfi-616.png
# Converted: bfi-2466.jpg → bfi-2466.png
# Converted: nissl-2365.jpg → nissl-2365.png
# Converted: bfi-1879.jpg → bfi-1879.png
# Converted: bfi-2323.jpg → bfi-2323.png
# Converted: bfi-1397.jpg → bfi-1397.png
# Converted: bfi-1095.jpg → bfi-1095.png
# Converted: nissl-451.jpg → nissl-451.png
# Converted: bfi-808.jpg → bfi-808.png
# Converted: nissl-2605.jpg → nissl-2605.png
# Converted: bfi-416.jpg → bfi-416.png
# Converted: bfi-1936.jpg → bfi-1936.png
# Converted: nissl-1936.jpg → nissl-1936.png
# Converted: bfi-1495.jpg → bfi-1495.png
# Converted: bfi-267.jpg → bfi-267.png
# Converted: bfi-331.jpg → bfi-331.png
# Converted: bfi-114.jpg → bfi-114.png
# Converted: nissl-1591.jpg → nissl-1591.png
# Converted: bfi-92.jpg → bfi-92.png
# Converted: bfi-574.jpg → bfi-574.png
# Converted: bfi-2008.jpg → bfi-2008.png
# Converted: nissl-1933.jpg → nissl-1933.png
# Converted: bfi-287.jpg → bfi-287.png
# Converted: nissl-1054.jpg → nissl-1054.png
# Converted: bfi-1608.jpg → bfi-1608.png
# Converted: bfi-454.jpg → bfi-454.png
# Converted: bfi-470.jpg → bfi-470.png
# Converted: bfi-599.jpg → bfi-599.png
# Converted: nissl-1588.jpg → nissl-1588.png
# Converted: bfi-218.jpg → bfi-218.png
# Converted: nissl-1783.jpg → nissl-1783.png
# Converted: bfi-1894.jpg → bfi-1894.png
# Converted: bfi-1901.jpg → bfi-1901.png
# Converted: bfi-512.jpg → bfi-512.png
# Converted: bfi-1995.jpg → bfi-1995.png
# Converted: bfi-1675.jpg → bfi-1675.png
# Converted: bfi-2437.jpg → bfi-2437.png
# Converted: nissl-874.jpg → nissl-874.png
# Converted: bfi-1811.jpg → bfi-1811.png
# Converted: bfi-1599.jpg → bfi-1599.png
# Converted: bfi-534.jpg → bfi-534.png
# Converted: bfi-1372.jpg → bfi-1372.png
# Converted: bfi-274.jpg → bfi-274.png
# Converted: nissl-2203.jpg → nissl-2203.png
# Converted: bfi-881.jpg → bfi-881.png
# Converted: bfi-2141.jpg → bfi-2141.png
# Converted: bfi-367.jpg → bfi-367.png
# Converted: bfi-1718.jpg → bfi-1718.png
# Converted: bfi-101.jpg → bfi-101.png
# Converted: bfi-2273.jpg → bfi-2273.png
# Converted: bfi-853.jpg → bfi-853.png
# Converted: bfi-302.jpg → bfi-302.png
# Converted: bfi-356.jpg → bfi-356.png
# Converted: bfi-135.jpg → bfi-135.png
# Converted: bfi-1800.jpg → bfi-1800.png
# Converted: bfi-1235.jpg → bfi-1235.png
# Converted: nissl-2416.jpg → nissl-2416.png
# Converted: nissl-2011.jpg → nissl-2011.png
# Converted: bfi-133.jpg → bfi-133.png
# Converted: nissl-1930.jpg → nissl-1930.png
# Converted: bfi-763.jpg → bfi-763.png
# Converted: bfi-2487.jpg → bfi-2487.png
# Converted: bfi-1034.jpg → bfi-1034.png
# Converted: bfi-1588.jpg → bfi-1588.png
# Converted: bfi-1524.jpg → bfi-1524.png
# Converted: nissl-229.jpg → nissl-229.png
# Converted: nissl-643.jpg → nissl-643.png
# Converted: bfi-1657.jpg → bfi-1657.png
# Converted: bfi-448.jpg → bfi-448.png
# Converted: bfi-1809.jpg → bfi-1809.png
# Converted: bfi-1227.jpg → bfi-1227.png
# Converted: bfi-635.jpg → bfi-635.png
# Converted: nissl-1075.jpg → nissl-1075.png
# Converted: bfi-2246.jpg → bfi-2246.png
# Converted: bfi-2129.jpg → bfi-2129.png
# Converted: bfi-296.jpg → bfi-296.png
# Converted: nissl-1327.jpg → nissl-1327.png
# Converted: bfi-2376.jpg → bfi-2376.png
# Converted: bfi-787.jpg → bfi-787.png
# Converted: bfi-2375.jpg → bfi-2375.png
# Converted: bfi-1837.jpg → bfi-1837.png
# Converted: bfi-1976.jpg → bfi-1976.png
# Converted: bfi-300.jpg → bfi-300.png
# Converted: bfi-856.jpg → bfi-856.png
# Converted: bfi-952.jpg → bfi-952.png
# Converted: bfi-2079.jpg → bfi-2079.png
# Converted: bfi-360.jpg → bfi-360.png
# Converted: bfi-2036.jpg → bfi-2036.png
# Converted: nissl-25.jpg → nissl-25.png
# Converted: bfi-1760.jpg → bfi-1760.png
# Converted: bfi-633.jpg → bfi-633.png
# Converted: bfi-1012.jpg → bfi-1012.png
# Converted: bfi-694.jpg → bfi-694.png
# Converted: bfi-1558.jpg → bfi-1558.png
# Converted: nissl-178.jpg → nissl-178.png
# Converted: bfi-323.jpg → bfi-323.png
# Converted: bfi-253.jpg → bfi-253.png
# Converted: bfi-832.jpg → bfi-832.png
# Converted: bfi-498.jpg → bfi-498.png
# Converted: bfi-1808.jpg → bfi-1808.png
# Converted: bfi-1738.jpg → bfi-1738.png
# Converted: nissl-1096.jpg → nissl-1096.png
# Converted: bfi-997.jpg → bfi-997.png
# Converted: bfi-190.jpg → bfi-190.png
# Converted: bfi-794.jpg → bfi-794.png
# Converted: bfi-2425.jpg → bfi-2425.png
# Converted: bfi-1461.jpg → bfi-1461.png
# Converted: bfi-1670.jpg → bfi-1670.png
# Converted: bfi-183.jpg → bfi-183.png
# Converted: bfi-223.jpg → bfi-223.png
# Converted: nissl-1666.jpg → nissl-1666.png
# Converted: nissl-1975.jpg → nissl-1975.png
# Converted: bfi-1139.jpg → bfi-1139.png
# Converted: bfi-844.jpg → bfi-844.png
# Converted: nissl-2317.jpg → nissl-2317.png
# Converted: bfi-1753.jpg → bfi-1753.png
# Converted: bfi-989.jpg → bfi-989.png
# Converted: bfi-257.jpg → bfi-257.png
# Converted: bfi-352.jpg → bfi-352.png
# Converted: bfi-2.jpg → bfi-2.png
# Converted: bfi-1855.jpg → bfi-1855.png
# Converted: nissl-1393.jpg → nissl-1393.png
# Converted: bfi-2131.jpg → bfi-2131.png
# Converted: bfi-1839.jpg → bfi-1839.png
# Converted: bfi-1242.jpg → bfi-1242.png
# Converted: nissl-58.jpg → nissl-58.png
# Converted: bfi-2403.jpg → bfi-2403.png
# Converted: nissl-1786.jpg → nissl-1786.png
# Converted: nissl-1711.jpg → nissl-1711.png
# Converted: bfi-1173.jpg → bfi-1173.png
# Converted: bfi-964.jpg → bfi-964.png
# Converted: nissl-757.jpg → nissl-757.png
# Converted: bfi-1415.jpg → bfi-1415.png
# Converted: bfi-1789.jpg → bfi-1789.png
# Converted: bfi-902.jpg → bfi-902.png
# Converted: nissl-463.jpg → nissl-463.png
# Converted: bfi-1998.jpg → bfi-1998.png
# Converted: bfi-932.jpg → bfi-932.png
# Converted: nissl-1216.jpg → nissl-1216.png
# Converted: bfi-2324.jpg → bfi-2324.png
# Converted: bfi-452.jpg → bfi-452.png
# Converted: nissl-1129.jpg → nissl-1129.png
# Converted: bfi-1610.jpg → bfi-1610.png
# Converted: nissl-955.jpg → nissl-955.png
# Converted: bfi-1966.jpg → bfi-1966.png
# Converted: bfi-393.jpg → bfi-393.png
# Converted: bfi-1322.jpg → bfi-1322.png
# Converted: bfi-4.jpg → bfi-4.png
# Converted: bfi-375.jpg → bfi-375.png
# Converted: bfi-2489.jpg → bfi-2489.png
# Converted: bfi-699.jpg → bfi-699.png
# Converted: bfi-2075.jpg → bfi-2075.png
# Converted: bfi-602.jpg → bfi-602.png
# Converted: bfi-2012.jpg → bfi-2012.png
# Converted: bfi-992.jpg → bfi-992.png
# Converted: nissl-1246.jpg → nissl-1246.png
# Converted: bfi-1019.jpg → bfi-1019.png
# Converted: bfi-2362.jpg → bfi-2362.png
# Converted: bfi-850.jpg → bfi-850.png
# Converted: nissl-1399.jpg → nissl-1399.png
# Converted: bfi-203.jpg → bfi-203.png
# Converted: bfi-606.jpg → bfi-606.png
# Converted: bfi-86.jpg → bfi-86.png
# Converted: nissl-418.jpg → nissl-418.png
# Converted: bfi-1279.jpg → bfi-1279.png
# Converted: bfi-193.jpg → bfi-193.png
# Converted: bfi-906.jpg → bfi-906.png
# Converted: bfi-197.jpg → bfi-197.png
# Converted: bfi-814.jpg → bfi-814.png
# Converted: nissl-1849.jpg → nissl-1849.png
# Converted: bfi-282.jpg → bfi-282.png
# Converted: bfi-1043.jpg → bfi-1043.png
# Converted: nissl-1882.jpg → nissl-1882.png
# Converted: bfi-1592.jpg → bfi-1592.png
# Converted: bfi-1355.jpg → bfi-1355.png
# Converted: bfi-1528.jpg → bfi-1528.png
# Converted: bfi-2017.jpg → bfi-2017.png
# Converted: bfi-358.jpg → bfi-358.png
# Converted: bfi-1959.jpg → bfi-1959.png
# Converted: bfi-256.jpg → bfi-256.png
# Converted: nissl-49.jpg → nissl-49.png
# Converted: nissl-2053.jpg → nissl-2053.png
# Converted: bfi-1476.jpg → bfi-1476.png
# Converted: bfi-1587.jpg → bfi-1587.png
# Converted: bfi-1805.jpg → bfi-1805.png
# Converted: bfi-2424.jpg → bfi-2424.png
# Converted: bfi-2316.jpg → bfi-2316.png
# Converted: bfi-1556.jpg → bfi-1556.png
# Converted: bfi-1205.jpg → bfi-1205.png
# Converted: bfi-1856.jpg → bfi-1856.png
# Converted: bfi-1059.jpg → bfi-1059.png
# Converted: bfi-1496.jpg → bfi-1496.png
# Converted: bfi-624.jpg → bfi-624.png
# Converted: nissl-1357.jpg → nissl-1357.png
# Converted: bfi-1613.jpg → bfi-1613.png
# Converted: bfi-1612.jpg → bfi-1612.png
# Converted: bfi-2016.jpg → bfi-2016.png
# Converted: nissl-394.jpg → nissl-394.png
# Converted: nissl-1678.jpg → nissl-1678.png
# Converted: nissl-2608.jpg → nissl-2608.png
# Converted: bfi-804.jpg → bfi-804.png
# Converted: bfi-701.jpg → bfi-701.png
# Converted: nissl-2470.jpg → nissl-2470.png
# Converted: nissl-2200.jpg → nissl-2200.png
# Converted: bfi-438.jpg → bfi-438.png
# Converted: bfi-285.jpg → bfi-285.png
# Converted: bfi-229.jpg → bfi-229.png
# Converted: bfi-849.jpg → bfi-849.png
# Converted: bfi-1598.jpg → bfi-1598.png
# Converted: nissl-565.jpg → nissl-565.png
# Converted: bfi-2224.jpg → bfi-2224.png
# Converted: bfi-312.jpg → bfi-312.png
# Converted: bfi-2307.jpg → bfi-2307.png
# Converted: bfi-1667.jpg → bfi-1667.png
# Converted: bfi-414.jpg → bfi-414.png
# Converted: bfi-1164.jpg → bfi-1164.png
# Converted: bfi-304.jpg → bfi-304.png
# Converted: bfi-1862.jpg → bfi-1862.png
# Converted: bfi-2454.jpg → bfi-2454.png
# Converted: bfi-239.jpg → bfi-239.png
# Converted: nissl-958.jpg → nissl-958.png
# Converted: bfi-2328.jpg → bfi-2328.png
# Converted: bfi-940.jpg → bfi-940.png
# Converted: bfi-2158.jpg → bfi-2158.png
# Converted: bfi-1300.jpg → bfi-1300.png
# Converted: bfi-188.jpg → bfi-188.png
# Converted: bfi-1140.jpg → bfi-1140.png
# Converted: bfi-17.jpg → bfi-17.png
# Converted: nissl-427.jpg → nissl-427.png
# Converted: bfi-1115.jpg → bfi-1115.png
# Converted: bfi-194.jpg → bfi-194.png
# Converted: nissl-298.jpg → nissl-298.png
# Converted: nissl-1432.jpg → nissl-1432.png
# Converted: bfi-123.jpg → bfi-123.png
# Converted: nissl-838.jpg → nissl-838.png
# Converted: bfi-1426.jpg → bfi-1426.png
# Converted: bfi-2461.jpg → bfi-2461.png
# Converted: bfi-1293.jpg → bfi-1293.png
# Converted: bfi-164.jpg → bfi-164.png
# Converted: bfi-2482.jpg → bfi-2482.png
# Converted: nissl-1231.jpg → nissl-1231.png
# Converted: nissl-793.jpg → nissl-793.png
# Converted: nissl-1996.jpg → nissl-1996.png
# Converted: bfi-1926.jpg → bfi-1926.png
# Converted: bfi-2151.jpg → bfi-2151.png
# Converted: nissl-1927.jpg → nissl-1927.png
# Converted: bfi-372.jpg → bfi-372.png
# Converted: bfi-2351.jpg → bfi-2351.png
# Converted: bfi-2484.jpg → bfi-2484.png
# Converted: bfi-1864.jpg → bfi-1864.png
# Converted: bfi-1498.jpg → bfi-1498.png
# Converted: bfi-2337.jpg → bfi-2337.png
# Converted: nissl-1204.jpg → nissl-1204.png
# Converted: bfi-923.jpg → bfi-923.png
# Converted: bfi-110.jpg → bfi-110.png
# Converted: nissl-241.jpg → nissl-241.png
# Converted: bfi-737.jpg → bfi-737.png
# Converted: bfi-640.jpg → bfi-640.png
# Converted: bfi-2305.jpg → bfi-2305.png
# Converted: bfi-2165.jpg → bfi-2165.png
# Converted: bfi-1170.jpg → bfi-1170.png
# Converted: bfi-260.jpg → bfi-260.png
# Converted: bfi-1767.jpg → bfi-1767.png
# Converted: bfi-904.jpg → bfi-904.png
# Converted: bfi-99.jpg → bfi-99.png
# Converted: bfi-540.jpg → bfi-540.png
# Converted: bfi-2483.jpg → bfi-2483.png
# Converted: bfi-555.jpg → bfi-555.png
# Converted: bfi-1953.jpg → bfi-1953.png
# Converted: bfi-2284.jpg → bfi-2284.png
# Converted: bfi-1846.jpg → bfi-1846.png
# Converted: bfi-1298.jpg → bfi-1298.png
# Converted: bfi-782.jpg → bfi-782.png
# Converted: bfi-1246.jpg → bfi-1246.png
# Converted: bfi-2317.jpg → bfi-2317.png
# Converted: bfi-1634.jpg → bfi-1634.png
# Converted: nissl-1084.jpg → nissl-1084.png
# Converted: bfi-1487.jpg → bfi-1487.png
# Converted: bfi-810.jpg → bfi-810.png
# Converted: bfi-629.jpg → bfi-629.png
# Converted: bfi-1447.jpg → bfi-1447.png
# Converted: bfi-2247.jpg → bfi-2247.png
# Converted: nissl-985.jpg → nissl-985.png
# Converted: bfi-1028.jpg → bfi-1028.png
# Converted: bfi-1568.jpg → bfi-1568.png
# Converted: bfi-1665.jpg → bfi-1665.png
# Converted: bfi-1540.jpg → bfi-1540.png
# Converted: nissl-1777.jpg → nissl-1777.png
# Converted: nissl-967.jpg → nissl-967.png
# Converted: nissl-1756.jpg → nissl-1756.png
# Converted: bfi-1581.jpg → bfi-1581.png
# Converted: nissl-1420.jpg → nissl-1420.png
# Converted: bfi-170.jpg → bfi-170.png
# Converted: bfi-1987.jpg → bfi-1987.png
# Converted: bfi-1694.jpg → bfi-1694.png
# Converted: nissl-1543.jpg → nissl-1543.png
# Converted: nissl-2095.jpg → nissl-2095.png
# Converted: bfi-444.jpg → bfi-444.png
# Converted: bfi-1268.jpg → bfi-1268.png
# Converted: bfi-261.jpg → bfi-261.png
# Converted: bfi-641.jpg → bfi-641.png
# Converted: bfi-1542.jpg → bfi-1542.png
# Converted: bfi-1340.jpg → bfi-1340.png
# Converted: bfi-917.jpg → bfi-917.png
# Converted: nissl-2176.jpg → nissl-2176.png
# Converted: bfi-776.jpg → bfi-776.png
# Converted: bfi-49.jpg → bfi-49.png
# Converted: nissl-1363.jpg → nissl-1363.png
# Converted: bfi-945.jpg → bfi-945.png
# Converted: bfi-2479.jpg → bfi-2479.png
# Converted: nissl-157.jpg → nissl-157.png
# Converted: bfi-440.jpg → bfi-440.png
# Converted: bfi-525.jpg → bfi-525.png
# Converted: bfi-2463.jpg → bfi-2463.png
# Converted: bfi-1797.jpg → bfi-1797.png
# Converted: bfi-993.jpg → bfi-993.png
# Converted: nissl-1846.jpg → nissl-1846.png
# Converted: bfi-2309.jpg → bfi-2309.png
# Converted: bfi-1295.jpg → bfi-1295.png
# Converted: bfi-351.jpg → bfi-351.png
# Converted: bfi-2208.jpg → bfi-2208.png
# Converted: nissl-1360.jpg → nissl-1360.png
# Converted: nissl-601.jpg → nissl-601.png
# ...
# Converted: nissl-1921.jpg → nissl-1921.png
# Converted: bfi-392.jpg → bfi-392.png
# Converted: nissl-2545.jpg → nissl-2545.png
# Converted: bfi-471.jpg → bfi-471.png
# Converted: nissl-1816.jpg → nissl-1816.png
# Converted: bfi-1803.jpg → bfi-1803.png
# Converted: nissl-1759.jpg → nissl-1759.png
# Converted: bfi-2325.jpg → bfi-2325.png
# Converted: bfi-1985.jpg → bfi-1985.png
# Converted: bfi-104.jpg → bfi-104.png
# Converted: bfi-762.jpg → bfi-762.png
# Converted: bfi-16.jpg → bfi-16.png
# Converted: bfi-2436.jpg → bfi-2436.png
# Converted: bfi-1964.jpg → bfi-1964.png
# Converted: bfi-1036.jpg → bfi-1036.png
# Converted: bfi-588.jpg → bfi-588.png
# Converted: bfi-1830.jpg → bfi-1830.png
# Converted: bfi-1965.jpg → bfi-1965.png
# Converted: bfi-235.jpg → bfi-235.png
# Converted: bfi-2022.jpg → bfi-2022.png
# Converted: bfi-191.jpg → bfi-191.png
# Converted: bfi-1069.jpg → bfi-1069.png
# Converted: bfi-2321.jpg → bfi-2321.png
# Converted: bfi-409.jpg → bfi-409.png
# Converted: bfi-2365.jpg → bfi-2365.png
# Converted: bfi-733.jpg → bfi-733.png
# Converted: nissl-760.jpg → nissl-760.png
# Converted: bfi-2102.jpg → bfi-2102.png
# Converted: bfi-589.jpg → bfi-589.png
# Converted: bfi-1997.jpg → bfi-1997.png
# Converted: bfi-2015.jpg → bfi-2015.png
# Converted: bfi-862.jpg → bfi-862.png
# Converted: bfi-957.jpg → bfi-957.png
# Converted: bfi-1184.jpg → bfi-1184.png
# Converted: bfi-1991.jpg → bfi-1991.png
# Converted: bfi-1313.jpg → bfi-1313.png
# Converted: bfi-1308.jpg → bfi-1308.png
# Converted: bfi-328.jpg → bfi-328.png
# Converted: bfi-148.jpg → bfi-148.png
# Converted: nissl-1498.jpg → nissl-1498.png
# Converted: nissl-2359.jpg → nissl-2359.png
# Converted: bfi-1680.jpg → bfi-1680.png
# Converted: nissl-1468.jpg → nissl-1468.png
# Converted: bfi-1772.jpg → bfi-1772.png
# Converted: nissl-1342.jpg → nissl-1342.png
# Converted: bfi-1782.jpg → bfi-1782.png
# Converted: bfi-317.jpg → bfi-317.png
# Converted: bfi-1174.jpg → bfi-1174.png
# Converted: bfi-1549.jpg → bfi-1549.png
# Converted: bfi-1301.jpg → bfi-1301.png
# Converted: bfi-1654.jpg → bfi-1654.png
# Converted: bfi-2288.jpg → bfi-2288.png
# Converted: bfi-1882.jpg → bfi-1882.png
# Converted: bfi-252.jpg → bfi-252.png
# Converted: nissl-1042.jpg → nissl-1042.png
# Converted: bfi-2126.jpg → bfi-2126.png
# Converted: bfi-1523.jpg → bfi-1523.png
# Converted: bfi-2227.jpg → bfi-2227.png
# Converted: bfi-1531.jpg → bfi-1531.png
# Converted: bfi-1077.jpg → bfi-1077.png
# Converted: nissl-514.jpg → nissl-514.png
# Converted: bfi-903.jpg → bfi-903.png
# Converted: bfi-1437.jpg → bfi-1437.png
# Converted: bfi-2116.jpg → bfi-2116.png
# Converted: bfi-607.jpg → bfi-607.png
# Converted: nissl-895.jpg → nissl-895.png
# Converted: bfi-1421.jpg → bfi-1421.png
# Converted: bfi-451.jpg → bfi-451.png
# Converted: bfi-1206.jpg → bfi-1206.png
# Converted: nissl-979.jpg → nissl-979.png
# Converted: bfi-735.jpg → bfi-735.png
# Converted: bfi-1458.jpg → bfi-1458.png
# Converted: bfi-608.jpg → bfi-608.png
# Converted: bfi-1943.jpg → bfi-1943.png
# Converted: bfi-293.jpg → bfi-293.png
# Converted: bfi-1339.jpg → bfi-1339.png
# Converted: bfi-1243.jpg → bfi-1243.png
# Converted: bfi-1868.jpg → bfi-1868.png
# Converted: bfi-1500.jpg → bfi-1500.png
# Converted: bfi-1102.jpg → bfi-1102.png
# Converted: bfi-2159.jpg → bfi-2159.png
# Converted: bfi-1777.jpg → bfi-1777.png
# Converted: bfi-1818.jpg → bfi-1818.png
# Converted: bfi-2214.jpg → bfi-2214.png
# Converted: bfi-1120.jpg → bfi-1120.png
# Converted: nissl-1768.jpg → nissl-1768.png
# Converted: bfi-1916.jpg → bfi-1916.png
# Converted: nissl-700.jpg → nissl-700.png
# Converted: bfi-491.jpg → bfi-491.png
# Converted: nissl-553.jpg → nissl-553.png
# Converted: nissl-1453.jpg → nissl-1453.png
# Converted: bfi-2274.jpg → bfi-2274.png
# Converted: bfi-161.jpg → bfi-161.png
# Converted: bfi-365.jpg → bfi-365.png
# Converted: bfi-1035.jpg → bfi-1035.png
# Converted: bfi-189.jpg → bfi-189.png
# Converted: bfi-1947.jpg → bfi-1947.png
# Converted: bfi-767.jpg → bfi-767.png
# Converted: bfi-2258.jpg → bfi-2258.png
# Converted: bfi-2313.jpg → bfi-2313.png
# Converted: bfi-1932.jpg → bfi-1932.png
# Converted: bfi-1751.jpg → bfi-1751.png
# Converted: bfi-1377.jpg → bfi-1377.png
# Converted: bfi-765.jpg → bfi-765.png
# Converted: bfi-1622.jpg → bfi-1622.png
# Converted: bfi-1319.jpg → bfi-1319.png
# Converted: bfi-426.jpg → bfi-426.png
# Converted: bfi-1996.jpg → bfi-1996.png
# Converted: bfi-1328.jpg → bfi-1328.png
# Converted: bfi-359.jpg → bfi-359.png
# Converted: bfi-14.jpg → bfi-14.png
# Converted: nissl-1729.jpg → nissl-1729.png
# Converted: bfi-819.jpg → bfi-819.png
# Converted: bfi-2185.jpg → bfi-2185.png
# Converted: nissl-1597.jpg → nissl-1597.png
# Converted: bfi-1050.jpg → bfi-1050.png
# Converted: bfi-2294.jpg → bfi-2294.png
# Converted: bfi-1111.jpg → bfi-1111.png
# Converted: bfi-1875.jpg → bfi-1875.png
# Converted: bfi-1677.jpg → bfi-1677.png
# Converted: nissl-412.jpg → nissl-412.png
# Converted: bfi-710.jpg → bfi-710.png
# Converted: bfi-1464.jpg → bfi-1464.png
# Converted: bfi-1570.jpg → bfi-1570.png
# Converted: nissl-1315.jpg → nissl-1315.png
# Converted: bfi-1589.jpg → bfi-1589.png
# Converted: nissl-118.jpg → nissl-118.png
# Converted: bfi-1529.jpg → bfi-1529.png
# Converted: bfi-2306.jpg → bfi-2306.png
# Converted: bfi-1460.jpg → bfi-1460.png
# Converted: nissl-580.jpg → nissl-580.png
# Converted: bfi-2357.jpg → bfi-2357.png
# Converted: bfi-1711.jpg → bfi-1711.png
# Converted: bfi-1692.jpg → bfi-1692.png
# Converted: bfi-35.jpg → bfi-35.png
# Converted: bfi-417.jpg → bfi-417.png
# Converted: bfi-2393.jpg → bfi-2393.png
# Converted: nissl-961.jpg → nissl-961.png
# Converted: nissl-1015.jpg → nissl-1015.png
# Converted: bfi-2451.jpg → bfi-2451.png
# Converted: bfi-1178.jpg → bfi-1178.png
# Converted: bfi-2202.jpg → bfi-2202.png
# Converted: nissl-1138.jpg → nissl-1138.png
# Converted: bfi-247.jpg → bfi-247.png
# Converted: bfi-1003.jpg → bfi-1003.png
# Converted: bfi-201.jpg → bfi-201.png
# Converted: bfi-913.jpg → bfi-913.png
# Converted: bfi-1027.jpg → bfi-1027.png
# Converted: nissl-2614.jpg → nissl-2614.png
# Converted: nissl-1675.jpg → nissl-1675.png
# Converted: nissl-265.jpg → nissl-265.png
# Converted: bfi-1764.jpg → bfi-1764.png
# Converted: nissl-1273.jpg → nissl-1273.png
# Converted: bfi-1317.jpg → bfi-1317.png
# Converted: bfi-1554.jpg → bfi-1554.png
# Converted: bfi-1259.jpg → bfi-1259.png
# Converted: bfi-2117.jpg → bfi-2117.png
# Converted: nissl-2068.jpg → nissl-2068.png
# Converted: bfi-2138.jpg → bfi-2138.png
# Converted: bfi-511.jpg → bfi-511.png
# Converted: bfi-2430.jpg → bfi-2430.png
# Converted: bfi-1060.jpg → bfi-1060.png
# Converted: bfi-387.jpg → bfi-387.png
# Converted: nissl-1267.jpg → nissl-1267.png
# Converted: bfi-523.jpg → bfi-523.png
# Converted: bfi-185.jpg → bfi-185.png
# Converted: bfi-2416.jpg → bfi-2416.png
# Converted: nissl-2440.jpg → nissl-2440.png
# Converted: bfi-691.jpg → bfi-691.png
# Converted: nissl-742.jpg → nissl-742.png
# Converted: bfi-1899.jpg → bfi-1899.png
# Converted: nissl-1495.jpg → nissl-1495.png
# Converted: bfi-2275.jpg → bfi-2275.png
# Converted: nissl-772.jpg → nissl-772.png
# Converted: bfi-631.jpg → bfi-631.png
# Converted: bfi-1557.jpg → bfi-1557.png
# Converted: bfi-708.jpg → bfi-708.png
# Converted: bfi-228.jpg → bfi-228.png
# Converted: nissl-2179.jpg → nissl-2179.png
# Converted: nissl-2191.jpg → nissl-2191.png
# Converted: bfi-142.jpg → bfi-142.png
# Converted: bfi-2368.jpg → bfi-2368.png
# Converted: nissl-2308.jpg → nissl-2308.png
# Converted: nissl-1369.jpg → nissl-1369.png
# Converted: bfi-262.jpg → bfi-262.png
# Converted: bfi-2031.jpg → bfi-2031.png
# Converted: bfi-2019.jpg → bfi-2019.png
# Converted: bfi-473.jpg → bfi-473.png
# Converted: bfi-597.jpg → bfi-597.png
# Converted: bfi-2001.jpg → bfi-2001.png
# Converted: nissl-1033.jpg → nissl-1033.png
# Converted: bfi-2042.jpg → bfi-2042.png
# Converted: bfi-892.jpg → bfi-892.png
# Converted: bfi-2086.jpg → bfi-2086.png
# Converted: bfi-1646.jpg → bfi-1646.png
# Converted: bfi-1615.jpg → bfi-1615.png
# Converted: nissl-2278.jpg → nissl-2278.png
# Converted: bfi-632.jpg → bfi-632.png
# Converted: bfi-2171.jpg → bfi-2171.png
# Converted: bfi-592.jpg → bfi-592.png
# Converted: bfi-2009.jpg → bfi-2009.png
# Converted: bfi-1591.jpg → bfi-1591.png
# Converted: nissl-931.jpg → nissl-931.png
# Converted: nissl-187.jpg → nissl-187.png
# Converted: bfi-1638.jpg → bfi-1638.png
# Converted: bfi-2431.jpg → bfi-2431.png
# Converted: bfi-829.jpg → bfi-829.png
# Converted: bfi-1776.jpg → bfi-1776.png
# Converted: bfi-2345.jpg → bfi-2345.png
# Converted: bfi-1136.jpg → bfi-1136.png
# Converted: bfi-668.jpg → bfi-668.png
# Converted: nissl-1417.jpg → nissl-1417.png
# Converted: bfi-2194.jpg → bfi-2194.png
# Converted: bfi-2112.jpg → bfi-2112.png
# Converted: nissl-664.jpg → nissl-664.png
# Converted: bfi-500.jpg → bfi-500.png
# Converted: bfi-2290.jpg → bfi-2290.png
# Converted: bfi-634.jpg → bfi-634.png
# Converted: nissl-523.jpg → nissl-523.png
# Converted: bfi-585.jpg → bfi-585.png
# Converted: bfi-1865.jpg → bfi-1865.png
# Converted: bfi-1271.jpg → bfi-1271.png
# Converted: bfi-726.jpg → bfi-726.png
# Converted: bfi-178.jpg → bfi-178.png
# Converted: bfi-1276.jpg → bfi-1276.png
# Converted: bfi-2091.jpg → bfi-2091.png
# Converted: bfi-1831.jpg → bfi-1831.png
# Converted: nissl-1636.jpg → nissl-1636.png
# Converted: bfi-2494.jpg → bfi-2494.png
# Converted: bfi-2366.jpg → bfi-2366.png
# Converted: nissl-1513.jpg → nissl-1513.png
# Converted: bfi-1600.jpg → bfi-1600.png
# Converted: bfi-2023.jpg → bfi-2023.png
# Converted: bfi-273.jpg → bfi-273.png
# Converted: bfi-1759.jpg → bfi-1759.png
# Converted: bfi-2199.jpg → bfi-2199.png
# Converted: bfi-2389.jpg → bfi-2389.png
# Converted: bfi-399.jpg → bfi-399.png
# Converted: bfi-1420.jpg → bfi-1420.png
# Converted: nissl-1048.jpg → nissl-1048.png
# Converted: nissl-682.jpg → nissl-682.png
# Converted: bfi-996.jpg → bfi-996.png
# Converted: bfi-1744.jpg → bfi-1744.png
# Converted: bfi-2331.jpg → bfi-2331.png
# Converted: bfi-2256.jpg → bfi-2256.png
# Converted: bfi-998.jpg → bfi-998.png
# Converted: bfi-885.jpg → bfi-885.png
# Converted: bfi-2191.jpg → bfi-2191.png
# Converted: nissl-1705.jpg → nissl-1705.png
# Converted: nissl-1189.jpg → nissl-1189.png
# Converted: nissl-1867.jpg → nissl-1867.png
# Converted: bfi-1345.jpg → bfi-1345.png
# Converted: bfi-1441.jpg → bfi-1441.png
# Converted: nissl-2098.jpg → nissl-2098.png
# Converted: bfi-890.jpg → bfi-890.png
# Converted: bfi-1478.jpg → bfi-1478.png
# Converted: bfi-477.jpg → bfi-477.png
# Converted: bfi-1607.jpg → bfi-1607.png
# Converted: bfi-1625.jpg → bfi-1625.png
# Converted: bfi-2329.jpg → bfi-2329.png
# Converted: bfi-2340.jpg → bfi-2340.png
# Converted: bfi-1360.jpg → bfi-1360.png
# Converted: bfi-1620.jpg → bfi-1620.png
# Converted: bfi-1363.jpg → bfi-1363.png
# Converted: bfi-1696.jpg → bfi-1696.png
# Converted: bfi-278.jpg → bfi-278.png
# Converted: bfi-1134.jpg → bfi-1134.png
# Converted: bfi-362.jpg → bfi-362.png
# Converted: nissl-259.jpg → nissl-259.png
# Converted: bfi-722.jpg → bfi-722.png
# Converted: bfi-1737.jpg → bfi-1737.png
# Converted: bfi-1256.jpg → bfi-1256.png
# Converted: bfi-663.jpg → bfi-663.png
# Converted: bfi-2286.jpg → bfi-2286.png
# Converted: bfi-937.jpg → bfi-937.png
# Converted: bfi-1544.jpg → bfi-1544.png
# Converted: nissl-2464.jpg → nissl-2464.png
# Converted: bfi-738.jpg → bfi-738.png
# Converted: bfi-907.jpg → bfi-907.png
# Converted: bfi-518.jpg → bfi-518.png
# Converted: bfi-1315.jpg → bfi-1315.png
# Converted: bfi-780.jpg → bfi-780.png
# Converted: bfi-1784.jpg → bfi-1784.png
# Converted: bfi-1107.jpg → bfi-1107.png
# Converted: bfi-120.jpg → bfi-120.png
# Converted: nissl-1333.jpg → nissl-1333.png
# Converted: bfi-1409.jpg → bfi-1409.png
# Converted: bfi-1261.jpg → bfi-1261.png
# Converted: bfi-2378.jpg → bfi-2378.png
# Converted: nissl-10.jpg → nissl-10.png
# Converted: bfi-83.jpg → bfi-83.png
# Converted: bfi-933.jpg → bfi-933.png
# Converted: bfi-674.jpg → bfi-674.png
# Converted: bfi-1497.jpg → bfi-1497.png
# Converted: bfi-2084.jpg → bfi-2084.png
# Converted: bfi-489.jpg → bfi-489.png
# Converted: nissl-1255.jpg → nissl-1255.png
# Converted: bfi-899.jpg → bfi-899.png
# Converted: nissl-988.jpg → nissl-988.png
# Converted: nissl-61.jpg → nissl-61.png
# Converted: nissl-1945.jpg → nissl-1945.png
# Converted: bfi-995.jpg → bfi-995.png
# Converted: nissl-2509.jpg → nissl-2509.png
# Converted: bfi-1413.jpg → bfi-1413.png
# Converted: bfi-127.jpg → bfi-127.png
# Converted: bfi-696.jpg → bfi-696.png
# Converted: nissl-973.jpg → nissl-973.png
# Converted: bfi-1016.jpg → bfi-1016.png
# Converted: bfi-2168.jpg → bfi-2168.png
# Converted: nissl-145.jpg → nissl-145.png
# Converted: bfi-1662.jpg → bfi-1662.png
# Converted: bfi-458.jpg → bfi-458.png
# Converted: bfi-1893.jpg → bfi-1893.png
# Converted: bfi-2096.jpg → bfi-2096.png
# Converted: bfi-1601.jpg → bfi-1601.png
# Converted: bfi-1412.jpg → bfi-1412.png
# Converted: bfi-2093.jpg → bfi-2093.png
# Converted: bfi-1852.jpg → bfi-1852.png
# Converted: bfi-905.jpg → bfi-905.png
# Converted: nissl-1561.jpg → nissl-1561.png
# Converted: bfi-1438.jpg → bfi-1438.png
# Converted: nissl-904.jpg → nissl-904.png
# Converted: bfi-118.jpg → bfi-118.png
# Converted: bfi-1477.jpg → bfi-1477.png
# Converted: bfi-2457.jpg → bfi-2457.png
# Converted: bfi-2381.jpg → bfi-2381.png
# Converted: bfi-1288.jpg → bfi-1288.png
# Converted: bfi-687.jpg → bfi-687.png
# Converted: bfi-2047.jpg → bfi-2047.png
# Converted: nissl-1120.jpg → nissl-1120.png
# Converted: bfi-478.jpg → bfi-478.png
# Converted: nissl-1801.jpg → nissl-1801.png
# Converted: bfi-2372.jpg → bfi-2372.png
# Converted: bfi-27.jpg → bfi-27.png
# Converted: nissl-1483.jpg → nissl-1483.png
# Converted: bfi-151.jpg → bfi-151.png
# Converted: bfi-806.jpg → bfi-806.png
# Converted: bfi-833.jpg → bfi-833.png
# Converted: bfi-1224.jpg → bfi-1224.png
# Converted: nissl-589.jpg → nissl-589.png
# Converted: bfi-30.jpg → bfi-30.png
# Converted: bfi-867.jpg → bfi-867.png
# Converted: bfi-1450.jpg → bfi-1450.png
# Converted: nissl-109.jpg → nissl-109.png
# Converted: nissl-391.jpg → nissl-391.png
# Converted: bfi-618.jpg → bfi-618.png
# Converted: bfi-418.jpg → bfi-418.png
# Converted: bfi-793.jpg → bfi-793.png
# Converted: nissl-913.jpg → nissl-913.png
# Converted: bfi-1040.jpg → bfi-1040.png
# Converted: bfi-2432.jpg → bfi-2432.png
# Converted: bfi-842.jpg → bfi-842.png
# Converted: nissl-1066.jpg → nissl-1066.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py:643, in _save(im, fp, tile, bufsize)
#     642 try:
# --> 643     fh = fp.fileno()
#     644     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 15
#      13 # Open and convert
#      14 with Image.open(jpg_path) as img:
# ---> 15     img.save(png_path)
#      17 print(f'Converted: {filename} → {os.path.basename(png_path)}')
#
# File /usr/local/lib/python3.10/dist-packages/PIL/Image.py:2581, in Image.save(self, fp, format, **params)
#    2578     fp = cast(IO[bytes], fp)
#    2580 try:
# -> 2581     save_handler(self, fp, filename)
#    2582 except Exception:
#    2583     if open_fp:
#
# File /usr/local/lib/python3.10/dist-packages/PIL/PngImagePlugin.py:1492, in _save(im, fp, filename, chunk, save_all)
#    1488     single_im = _write_multiple_frames(
#    1489         im, fp, chunk, mode, rawmode, default_image, append_images
#    1490     )
#    1491 if single_im:
# -> 1492     ImageFile._save(
#    1493         single_im,
#    1494         cast(IO[bytes], _idat(fp, chunk)),
#    1495         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1496     )
#    1498 if info:
#    1499     for info_chunk in info.chunks:
#
# File /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py:647, in _save(im, fp, tile, bufsize)
#     645     _encode_tile(im, fp, tile, bufsize, fh)
#     646 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 647     _encode_tile(im, fp, tile, bufsize, None, exc)
#     648 if hasattr(fp, "flush"):
#     649     fp.flush()
#
# File /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py:673, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     670 if exc:
#     671     # compress to Python file-compatible object
#     672     while True:
# --> 673         errcode, data = encoder.encode(bufsize)[1:]
#     674         fp.write(data)
#     675         if errcode:
#
# KeyboardInterrupt:
